# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

import RL1_Part2 as p2

# %% [markdown]
# # Part 2
# ## Gradual Changes - drift
# ### 1) Optimistic Greedy

# %%
environment = p2.Environment(change_type='gradual', gradual_mode=True)
evaluator = p2.MovingEvaluator(epsilon=0.0, env_change_type='gradual', env_gradual_mode=True, decreasing_step_size=False, update_method='incremental', run_count=1000, optimistic=True)
a1 = evaluator.run(preset_env=environment)
evaluator.visualize()

# %% [markdown]
# ### 2-0) eGreedy with fixed step size

# %%
evaluator = p2.MovingEvaluator(epsilon=0.1, env_change_type='gradual', env_gradual_mode=True, decreasing_step_size=False, update_method='incremental', run_count=1000, optimistic=False)
a20 = evaluator.run(preset_env=environment)
evaluator.visualize()

# %% [markdown]
# ### 2-1) eGreedy with fixed step size

# %%
evaluator = p2.MovingEvaluator(epsilon=0.15, env_change_type='gradual', env_gradual_mode=True, decreasing_step_size=False, update_method='incremental', run_count=1000, optimistic=False)
a21 = evaluator.run(preset_env=environment)
evaluator.visualize()

# %% [markdown]
# ### 2-2) eGreedy with fixed step size

# %%
evaluator = p2.MovingEvaluator(epsilon=0.2, env_change_type='gradual', env_gradual_mode=True, decreasing_step_size=False, update_method='incremental', run_count=1000, optimistic=False)
a22 = evaluator.run(preset_env=environment)
evaluator.visualize()

# %% [markdown]
# ### 2-3) eGreedy with fixed step size

# %%
evaluator = p2.MovingEvaluator(epsilon=0.25, env_change_type='gradual', env_gradual_mode=True, decreasing_step_size=False, update_method='incremental', run_count=1000, optimistic=False)
a23 = evaluator.run(preset_env=environment)
evaluator.visualize()

# %% [markdown]
# ### 2-4) eGreedy with fixed step size

# %%
evaluator = p2.MovingEvaluator(epsilon=0.3, env_change_type='gradual', env_gradual_mode=True, decreasing_step_size=False, update_method='incremental', run_count=1000, optimistic=False)
a24 = evaluator.run(preset_env=environment)
evaluator.visualize()

# %% [markdown]
# ### 2-5) eGreedy with fixed step size

# %%
evaluator = p2.MovingEvaluator(epsilon=0.4, env_change_type='gradual', env_gradual_mode=True, decreasing_step_size=False, update_method='incremental', run_count=1000, optimistic=False)
a25 = evaluator.run(preset_env=environment)
evaluator.visualize()

# %% [markdown]
# ### 3-0) eGreedy with decreasing step size

# %%
evaluator = p2.MovingEvaluator(epsilon=0.1, env_change_type='gradual', env_gradual_mode=True, decreasing_step_size=True, update_method='incremental', run_count=1000, optimistic=False, decay_rate=0.01)
a30 = evaluator.run(preset_env=environment)
evaluator.visualize()

# %% [markdown]
# ### 3-1) eGreedy with decreasing step size

# %%
evaluator = p2.MovingEvaluator(epsilon=0.15, env_change_type='gradual', env_gradual_mode=True, decreasing_step_size=True, update_method='incremental', run_count=1000, optimistic=False, decay_rate=0.01)
a31 = evaluator.run(preset_env=environment)
evaluator.visualize()

# %% [markdown]
# ### 3-2) eGreedy with decreasing step size

# %%
evaluator = p2.MovingEvaluator(epsilon=0.20, env_change_type='gradual', env_gradual_mode=True, decreasing_step_size=True, update_method='incremental', run_count=1000, optimistic=False, decay_rate=0.01)
a32 = evaluator.run(preset_env=environment)
evaluator.visualize()

# %% [markdown]
# ### 3-3) eGreedy with decreasing step size

# %%
evaluator = p2.MovingEvaluator(epsilon=0.25, env_change_type='gradual', env_gradual_mode=True, decreasing_step_size=True, update_method='incremental', run_count=1000, optimistic=False, decay_rate=0.01)
a33 = evaluator.run(preset_env=environment)
evaluator.visualize()

# %% [markdown]
# ### 3-4) eGreedy with decreasing step size

# %%
evaluator = p2.MovingEvaluator(epsilon=0.30, env_change_type='gradual', env_gradual_mode=True, decreasing_step_size=True, update_method='incremental', run_count=1000, optimistic=False, decay_rate=0.01)
a34 = evaluator.run(preset_env=environment)
evaluator.visualize()

# %% [markdown]
# ### 3-5) eGreedy with decreasing step size

# %%
evaluator = p2.MovingEvaluator(epsilon=0.40, env_change_type='gradual', env_gradual_mode=True, decreasing_step_size=True, update_method='incremental', run_count=1000, optimistic=False, decay_rate=0.01)
a35 = evaluator.run(preset_env=environment)
evaluator.visualize()

# %%
fig = plt.figure()
plt.grid(zorder=0)
plt.xlabel("Epsilon values")
plt.ylabel("Mean rewards")
plt.title("Model performance: Gradual changes - drift")
df = pd.DataFrame({'Optimistic e=0.00':a1, "Stationary e=0.10":a20, "Stationary e=0.15":a21, "Stationary e=0.20":a22, "Stationary e=0.25":a23, "Stationary e=0.30":a24, "Stationary e=0.40":a25, "Decreasing e=0.10":a30, "Decreasing e=0.15":a31, "Decreasing e=0.20":a32, "Decreasing e=0.25":a33, "Decreasing e=0.30":a34, "Decreasing e=0.40":a35})
plt.boxplot(df, labels=df.columns, showfliers=False)
plt.xticks(rotation=90)
plt.show()

# %%
# Out:
# Index(['Optimistic\ne=0', 'Stationary\ne=0.1', 'Stationary\ne=0.15',
#        'Stationary\ne=0.2', 'Stationary\ne=0.25', 'Stationary\ne=0.3',
#        'Stationary\ne=0.4', 'Decreasing\ne=0.1', 'Decreasing\ne=0.15',
#        'Decreasing\ne=0.2', 'Decreasing\ne=0.25', 'Decreasing\ne=0.3',
#        'Decreasing\ne=0.4'],
#       dtype='object')

# %% [markdown]
# ################################################################################################

# %% [markdown]
# ## Gradual Changes - mean-reverting
# ### 1) Optimistic Greedy

# %%
environment = p2.Environment(change_type='gradual', gradual_mode=False)
evaluator = p2.MovingEvaluator(epsilon=0.0, env_change_type='gradual', env_gradual_mode=False, decreasing_step_size=False, update_method='incremental', run_count=1000, optimistic=True)
b1 = evaluator.run(preset_env=environment)
evaluator.visualize()

# %% [markdown]
# ### 2-0) eGreedy with fixed step size

# %%
evaluator = p2.MovingEvaluator(epsilon=0.1, env_change_type='gradual', env_gradual_mode=False, decreasing_step_size=False, update_method='incremental', run_count=1000, optimistic=False)
b20 = evaluator.run(preset_env=environment)
evaluator.visualize()

# %% [markdown]
# ### 2-1) eGreedy with fixed step size

# %%
evaluator = p2.MovingEvaluator(epsilon=0.15, env_change_type='gradual', env_gradual_mode=False, decreasing_step_size=False, update_method='incremental', run_count=1000, optimistic=False)
b21 = evaluator.run(preset_env=environment)
evaluator.visualize()

# %% [markdown]
# ### 2-2) eGreedy with fixed step size

# %%
evaluator = p2.MovingEvaluator(epsilon=0.2, env_change_type='gradual', env_gradual_mode=False, decreasing_step_size=False, update_method='incremental', run_count=1000, optimistic=False)
b22 = evaluator.run(preset_env=environment)
evaluator.visualize()

# %% [markdown]
# ### 2-3) eGreedy with fixed step size

# %%
evaluator = p2.MovingEvaluator(epsilon=0.25, env_change_type='gradual', env_gradual_mode=False, decreasing_step_size=False, update_method='incremental', run_count=1000, optimistic=False)
b23 = evaluator.run(preset_env=environment)
evaluator.visualize()

# %% [markdown]
# ### 2-4) eGreedy with fixed step size

# %%
evaluator = p2.MovingEvaluator(epsilon=0.3, env_change_type='gradual', env_gradual_mode=False, decreasing_step_size=False, update_method='incremental', run_count=1000, optimistic=False)
b24 = evaluator.run(preset_env=environment)
evaluator.visualize()

# %% [markdown]
# ### 2-5) eGreedy with fixed step size

# %%
evaluator = p2.MovingEvaluator(epsilon=0.4, env_change_type='gradual', env_gradual_mode=False, decreasing_step_size=False, update_method='incremental', run_count=1000, optimistic=False)
b25 = evaluator.run(preset_env=environment)
evaluator.visualize()

# %% [markdown]
# ### 3-0) eGreedy with decreasing step size

# %%
evaluator = p2.MovingEvaluator(epsilon=0.1, env_change_type='gradual', env_gradual_mode=False, decreasing_step_size=True, update_method='incremental', run_count=1000, optimistic=False, decay_rate=0.01)
b30 = evaluator.run(preset_env=environment)
evaluator.visualize()

# %% [markdown]
# ### 3-1) eGreedy with decreasing step size

# %%
evaluator = p2.MovingEvaluator(epsilon=0.15, env_change_type='gradual', env_gradual_mode=False, decreasing_step_size=True, update_method='incremental', run_count=1000, optimistic=False, decay_rate=0.01)
b31 = evaluator.run(preset_env=environment)
evaluator.visualize()

# %% [markdown]
# ### 3-2) eGreedy with decreasing step size

# %%
evaluator = p2.MovingEvaluator(epsilon=0.2, env_change_type='gradual', env_gradual_mode=False, decreasing_step_size=True, update_method='incremental', run_count=1000, optimistic=False, decay_rate=0.01)
b32 = evaluator.run(preset_env=environment)
evaluator.visualize()

# %% [markdown]
# ### 3-3) eGreedy with decreasing step size

# %%
evaluator = p2.MovingEvaluator(epsilon=0.25, env_change_type='gradual', env_gradual_mode=False, decreasing_step_size=True, update_method='incremental', run_count=1000, optimistic=False, decay_rate=0.01)
b33 = evaluator.run(preset_env=environment)
evaluator.visualize()

# %% [markdown]
# ### 3-4) eGreedy with decreasing step size

# %%
evaluator = p2.MovingEvaluator(epsilon=0.30, env_change_type='gradual', env_gradual_mode=False, decreasing_step_size=True, update_method='incremental', run_count=1000, optimistic=False, decay_rate=0.01)
b34 = evaluator.run(preset_env=environment)
evaluator.visualize()

# %% [markdown]
# ### 3-5) eGreedy with decreasing step size

# %%
evaluator = p2.MovingEvaluator(epsilon=0.4, env_change_type='gradual', env_gradual_mode=False, decreasing_step_size=True, update_method='incremental', run_count=1000, optimistic=False, decay_rate=0.01)
b35 = evaluator.run(preset_env=environment)
evaluator.visualize()

# %%
fig = plt.figure()
plt.grid(zorder=0)
plt.xlabel("Epsilon values")
plt.ylabel("Mean rewards")
plt.title("Model performance: Gradual changes - mean reverting")
df = pd.DataFrame({'Optimistic e=0.00':b1, "Stationary e=0.10":b20, "Stationary e=0.15":b21, "Stationary e=0.20":b22, "Stationary e=0.25":b23, "Stationary e=0.30":b24, "Stationary e=0.40":b25, "Decreasing e=0.10":b30, "Decreasing e=0.15":b31, "Decreasing e=0.20":b32, "Decreasing e=0.25":b33, "Decreasing e=0.30":b34, "Decreasing e=0.40":b35})
plt.boxplot(df, labels=df.columns, showfliers=False)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ################################################################################################

# %% [markdown]
# ## Abrupt Changes
# ### 1) Optimistic Greedy

# %%
environment = p2.Environment(change_type='abrupt')
evaluator = p2.MovingEvaluator(epsilon=0.0, env_change_type='abrupt', decreasing_step_size=False, update_method='incremental', run_count=1000, optimistic=True)
c1 = evaluator.run(preset_env=environment)
evaluator.visualize()

# %% [markdown]
# ### 2-0) eGreedy with fixed step size

# %%
evaluator = p2.MovingEvaluator(epsilon=0.1, env_change_type='abrupt', decreasing_step_size=False, update_method='incremental', run_count=1000, optimistic=False)
c20 = evaluator.run(preset_env=environment)
evaluator.visualize()

# %% [markdown]
# ### 2-1) eGreedy with fixed step size

# %%
evaluator = p2.MovingEvaluator(epsilon=0.15, env_change_type='abrupt', decreasing_step_size=False, update_method='incremental', run_count=1000, optimistic=False)
c21 = evaluator.run(preset_env=environment)
evaluator.visualize()

# %% [markdown]
# ### 2-2) eGreedy with fixed step size

# %%
evaluator = p2.MovingEvaluator(epsilon=0.20, env_change_type='abrupt', decreasing_step_size=False, update_method='incremental', run_count=1000, optimistic=False)
c22 = evaluator.run(preset_env=environment)
evaluator.visualize()

# %% [markdown]
# ### 2-3) eGreedy with fixed step size

# %%
evaluator = p2.MovingEvaluator(epsilon=0.25, env_change_type='abrupt', decreasing_step_size=False, update_method='incremental', run_count=1000, optimistic=False)
c23 = evaluator.run(preset_env=environment)
evaluator.visualize()

# %% [markdown]
# ### 2-4) eGreedy with fixed step size

# %%
evaluator = p2.MovingEvaluator(epsilon=0.30, env_change_type='abrupt', decreasing_step_size=False, update_method='incremental', run_count=1000, optimistic=False)
c24 = evaluator.run(preset_env=environment)
evaluator.visualize()

# %% [markdown]
# ### 2-5) eGreedy with fixed step size

# %%
evaluator = p2.MovingEvaluator(epsilon=0.4, env_change_type='abrupt', decreasing_step_size=False, update_method='incremental', run_count=1000, optimistic=False)
c25 = evaluator.run(preset_env=environment)
evaluator.visualize()

# %% [markdown]
# ### 3-0) eGreedy with decreasing step size

# %%
evaluator = p2.MovingEvaluator(epsilon=0.1, env_change_type='abrupt', decreasing_step_size=True, update_method='incremental', run_count=1000, optimistic=False, decay_rate=0.01)
c30 = evaluator.run(preset_env=environment)
evaluator.visualize()

# %% [markdown]
# ### 3-1) eGreedy with decreasing step size

# %%
evaluator = p2.MovingEvaluator(epsilon=0.15, env_change_type='abrupt', decreasing_step_size=True, update_method='incremental', run_count=1000, optimistic=False, decay_rate=0.01)
c31 = evaluator.run(preset_env=environment)
evaluator.visualize()

# %% [markdown]
# ### 3-2) eGreedy with decreasing step size

# %%
evaluator = p2.MovingEvaluator(epsilon=0.2, env_change_type='abrupt', decreasing_step_size=True, update_method='incremental', run_count=1000, optimistic=False, decay_rate=0.01)
c32 = evaluator.run(preset_env=environment)
evaluator.visualize()

# %% [markdown]
# ### 3-3) eGreedy with decreasing step size

# %%
evaluator = p2.MovingEvaluator(epsilon=0.25, env_change_type='abrupt', decreasing_step_size=True, update_method='incremental', run_count=1000, optimistic=False, decay_rate=0.01)
c33 = evaluator.run(preset_env=environment)
evaluator.visualize()

# %% [markdown]
# ### 3-4) eGreedy with decreasing step size

# %%
evaluator = p2.MovingEvaluator(epsilon=0.30, env_change_type='abrupt', decreasing_step_size=True, update_method='incremental', run_count=1000, optimistic=False, decay_rate=0.01)
c34 = evaluator.run(preset_env=environment)
evaluator.visualize()

# %% [markdown]
# ### 3-5) eGreedy with decreasing step size

# %%
evaluator = p2.MovingEvaluator(epsilon=0.4, env_change_type='abrupt', decreasing_step_size=True, update_method='incremental', run_count=1000, optimistic=False, decay_rate=0.01)
c35 = evaluator.run(preset_env=environment)
evaluator.visualize()

# %%
fig = plt.figure()
plt.grid(zorder=0)
plt.xlabel("Epsilon values")
plt.ylabel("Mean rewards")
plt.title("Model performance: Abrupt changes")
df = pd.DataFrame({'Optimistic e=0.00':c1, "Stationary e=0.10":c20, "Stationary e=0.15":c21, "Stationary e=0.20":c22, "Stationary e=0.25":c23, "Stationary e=0.30":c24, "Stationary e=0.40":c25, "Decreasing e=0.10":c30, "Decreasing e=0.15":c31, "Decreasing e=0.20":c32, "Decreasing e=0.25":c33, "Decreasing e=0.30":c34, "Decreasing e=0.40":c35})
plt.boxplot(df, labels=df.columns, showfliers=False)
plt.xticks(rotation=90)
plt.show()
